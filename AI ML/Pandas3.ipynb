# %%
import pandas as pd

# %%
snr=pd.read_csv("csvfiles/names.csv",index_col="email")
snr.head()
# Out:
#                           first            last
# email
# john-doe@bogusemail.com    John             Doe
# maryjacobs@bogusemail.com  Mary  Smith-Robinson
# davesmith@bogusemail.com   Dave           Smith
# janestuart@bogusemail.com  Jane          Stuart
# tomwright@bogusemail.com    Tom          Wright

# %%
snr[:10]
# Out:
#                                first            last
# email
# john-doe@bogusemail.com         John             Doe
# maryjacobs@bogusemail.com       Mary  Smith-Robinson
# davesmith@bogusemail.com        Dave           Smith
# janestuart@bogusemail.com       Jane          Stuart
# tomwright@bogusemail.com         Tom          Wright
# steverobinson@bogusemail.com   Steve        Robinson
# nicolejacobs@bogusemail.com   Nicole          Jacobs
# janewright@bogusemail.com       Jane          Wright
# janedoe@bogusemail.com          Jane             Doe
# kurtwright@bogusemail.com       Kurt          Wright

# %%
snr[-1:-10:-1]
# Out:
#                                first       last
# email
# travisarnold@bogusemail.com   Travis     Arnold
# johnrobinson@bogusemail.com     John   Robinson
# travisarnold@bogusemail.com   Travis     Arnold
# janestuart@bogusemail.com       Jane     Stuart
# marypatterson@bogusemail.com    Mary  Patterson
# coreysmith@bogusemail.com      Corey      Smith
# coreywilks@bogusemail.com      Corey      Wilks
# neilsmith@bogusemail.com        Neil      Smith
# johnjacobs@bogusemail.com       John     Jacobs

# %%
snr['tomwright@bogusemail.com':]
# Out:
#                                  first       last
# email
# tomwright@bogusemail.com           Tom     Wright
# steverobinson@bogusemail.com     Steve   Robinson
# nicolejacobs@bogusemail.com     Nicole     Jacobs
# janewright@bogusemail.com         Jane     Wright
# janedoe@bogusemail.com            Jane        Doe
# kurtwright@bogusemail.com         Kurt     Wright
# kurtrobinson@bogusemail.com       Kurt   Robinson
# janejenkins@bogusemail.com        Jane    Jenkins
# neilrobinson@bogusemail.com       Neil   Robinson
# tompatterson@bogusemail.com        Tom  Patterson
# samjenkins@bogusemail.com          Sam    Jenkins
# stevestuart@bogusemail.com       Steve     Stuart
# maggiepatterson@bogusemail.com  Maggie  Patterson
# maggiestuart@bogusemail.com     Maggie     Stuart
# janedoe@bogusemail.com            Jane        Doe
# stevepatterson@bogusemail.com    Steve  Patterson
# davesmith@bogusemail.com          Dave      Smith
# samwilks@bogusemail.com            Sam      Wilks
# ...

# %%
#get method
snr.get(key=['janedoe@bogusemail.com'])
# Out:
# None

# %%
len(snr)
# Out:
# 44

# %%
snr.count()
# Out:
# first    44
# last     44
# dtype: int64
